# %% [markdown]
# # Challenge 1 - Tic Tac Toe
#
# In this lab you will perform deep learning analysis on a dataset of playing [Tic Tac Toe](https://en.wikipedia.org/wiki/Tic-tac-toe).
#
# There are 9 grids in Tic Tac Toe that are coded as the following picture shows:
#
# ![Tic Tac Toe Grids](tttboard.jpg)
#
# In the first 9 columns of the dataset you can find which marks (`x` or `o`) exist in the grids. If there is no mark in a certain grid, it is labeled as `b`. The last column is `class` which tells you whether Player X (who always moves first in Tic Tac Toe) wins in this configuration. Note that when `class` has the value `False`, it means either Player O wins the game or it ends up as a draw.

# %% [markdown]
# Follow the steps suggested below to conduct a neural network analysis using Tensorflow and Keras. You will build a deep learning model to predict whether Player X wins the game or not.
#
# ## Step 1: Data Engineering
#
# This dataset is almost in the ready-to-use state so you do not need to worry about missing values and so on. Still, some simple data engineering is needed.
#
# 1. Read `tic-tac-toe.csv` into a dataframe.
# 1. Inspect the dataset. Determine if the dataset is reliable by eyeballing the data.
# 1. Convert the categorical values to numeric in all columns.
# 1. Separate the inputs and output.
# 1. Normalize the input data.

# %%
# !pip install pandas
# !pip install scikit-learn
# !pip install tensorflow scikit-learn
# Out:
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached charset_normalizer-3.4.4-cp313-cp313-macosx_10_13_universal2.whl.metadata (37 kB)
# ...
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#   Using cached markupsafe-3.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.7 kB)
# ...
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.7/200.7 MB 1.6 MB/s  0:02:05m0:00:0100:04
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

df = pd.read_csv('./tic-tac-toe.csv')

# 2. Inspect the dataset
df
print(df.head())
print(df.info())
print(df['class'].value_counts())

encoder = LabelEncoder()
df_encoded = df.apply(encoder.fit_transform)

# 4. Separate inputs and target
X = df_encoded.drop("class", axis=1)
y = df_encoded["class"]

# 5. Normalize the inputs
# Neural networks learn better when all features are in the same range.
# MinMaxScaler scales every column to values between 0 and 1.
# It does NOT change the shape of the data or create new columns.
# It ONLY rescales the existing numbers. - it creates a new matrix: X_scaled
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

X_scaled[:5]
# Out:
#   TL TM TR ML MM MR BL BM BR  class
# 0  x  x  x  x  o  o  x  o  o   True
# 1  x  x  x  x  o  o  o  x  o   True
# 2  x  x  x  x  o  o  o  o  x   True
# 3  x  x  x  x  o  o  o  b  b   True
# 4  x  x  x  x  o  o  b  o  b   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TL      958 non-null    object
#  1   TM      958 non-null    object
#  2   TR      958 non-null    object
#  3   ML      958 non-null    object
#  4   MM      958 non-null    object
#  5   MR      958 non-null    object
#  6   BL      958 non-null    object
#  7   BM      958 non-null    object
#  8   BR      958 non-null    object
#  9   class   958 non-null    bool
# dtypes: bool(1), object(9)
# memory usage: 68.4+ KB
# None
# class
# True     626
# False    332
# Name: count, dtype: int64
# array([[1. , 1. , 1. , 1. , 0.5, 0.5, 1. , 0.5, 0.5],
# ...

# %% [markdown]
# ## Step 2: Build Neural Network
#
# To build the neural network, you can refer to your own codes you wrote while following the [Deep Learning with Python, TensorFlow, and Keras tutorial](https://www.youtube.com/watch?v=wQ8BIBpya2k) in the lesson. It's pretty similar to what you will be doing in this lab.
#
# 1. Split the training and test data.
# 1. Create a `Sequential` model.
# 1. Add several layers to your model. Make sure you use ReLU as the activation function for the middle layers. Use Softmax for the output layer because each output has a single lable and all the label probabilities add up to 1.
# 1. Compile the model using `adam` as the optimizer and `sparse_categorical_crossentropy` as the loss function. For metrics, use `accuracy` for now.
# 1. Fit the training data.
# 1. Evaluate your neural network model with the test data.
# 1. Save your model as `tic-tac-toe.model`.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# -------------------------------
# STEP 2: BUILD NEURAL NETWORK
# -------------------------------

model = Sequential()

# Add several layers to your model
model.add(Dense(32, input_dim=9, activation="relu")) # Input layer + first hidden layer (ReLU)
model.add(Dense(16, activation="relu")) # Second hidden layer (ReLU)
model.add(Dense(2, activation="softmax")) # Output layer (Softmax because we have 2 classes: X wins or not)

# Compile model
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# Train model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Evaluate model on test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")

# Save model (correct extension)
model.save("tic-tac-toe.keras")
# Out:
# /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 3/D1/lab-neural-networks/venvSofia/lib/python3.13/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - accuracy: 0.6149 - loss: 0.6719
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.6540 - loss: 0.6416
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.6540 - loss: 0.6323
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - accuracy: 0.6540 - loss: 0.6219
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - accuracy: 0.6606 - loss: 0.6120
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - accuracy: 0.6723 - loss: 0.6037
# Epoch 7/50
# ...

# %% [markdown]
# By Sofia:
#
# ### 🤔 What is overfitting (super simple)?
#
# Overfitting = the model learns the training data too well, including patterns that won’t show up in new data.
#
# It’s like memorizing the answers to past exams instead of understanding the material.
#
# So:
#
# - It performs great on the training data
# - It performs worse on new, unseen data (the test set)
#
# This is exactly what you’re seeing.
#
# ----
#
# ### 🚀 How to reduce overfitting (simple fixes)
# 1. Dropout
# 2. Reduce epochs (the longer you train the more the model memorizes)
# 3. Smaller model (Dense(16), Dense(8))
# 4. Early Stopping

# %% [markdown]
# ## Step 3: Make Predictions
#
# Now load your saved model and use it to make predictions on a few random rows in the test dataset. Check if the predictions are correct.

# %%
import numpy as np
import pandas as pd

from tensorflow.keras.models import load_model

# Load the saved model
model = load_model("tic-tac-toe.keras")

# Pick a few random rows from the test set
indices = np.random.choice(len(X_test), size=5, replace=False)

X_sample = X_test[indices]
y_sample = y_test.iloc[indices]

# Make predictions (probabilities)
pred_probs = model.predict(X_sample)

# Convert probabilities → class labels
pred_classes = np.argmax(pred_probs, axis=1)

print("Predictions:", pred_classes)
print("True Labels:", list(y_sample))

# Predictions in a nice table
df_results = pd.DataFrame({
    "Predicted": pred_classes,
    "Actual": y_sample.values
})

print(df_results)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predictions: [1 1 1 0 0]
# True Labels: [1, 1, 1, 0, 0]
#    Predicted  Actual
# 0          1       1
# 1          1       1
# 2          1       1
# 3          0       0
# 4          0       0

# %% [markdown]
# ## Step 4: Improve Your Model
#
# Did your model achieve low loss (<0.1) and high accuracy (>0.95)? If not, try to improve your model.
#
# But how? There are so many things you can play with in Tensorflow and in the next challenge you'll learn about these things. But in this challenge, let's just do a few things to see if they will help.
#
# * Add more layers to your model. If the data are complex you need more layers. But don't use more layers than you need. If adding more layers does not improve the model performance you don't need additional layers.
# * Adjust the learning rate when you compile the model. This means you will create a custom `tf.keras.optimizers.Adam` instance where you specify the learning rate you want. Then pass the instance to `model.compile` as the optimizer.
#     * `tf.keras.optimizers.Adam` [reference](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam).
#     * Don't worry if you don't understand what the learning rate does. You'll learn about it in the next challenge.
# * Adjust the number of epochs when you fit the training data to the model. Your model performance continues to improve as you train more epochs. But eventually it will reach the ceiling and the performance will stay the same.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Custom Adam optimizer with lower learning rate
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
optimizer_sgd = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
optimizer_rms = tf.keras.optimizers.RMSprop(learning_rate=0.001)
optimizer_adagrad = tf.keras.optimizers.Adagrad(learning_rate=0.01) # Good for sparse data, not always ideal for small datasets like tic-tac-toe.

model2 = Sequential([
    tf.keras.Input(shape=(9,)),

    Dense(64, activation="relu"),
    Dense(32, activation="relu"),
    Dense(16, activation="relu"),

    Dropout(0.2),

    Dense(2, activation="softmax")
])

# For loss you can use also: categorical_crossentropy, binary_crossentropy, mean_squared_error
model2.compile(
    optimizer=optimizer,
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history = model2.fit(
    X_train, y_train,
    epochs=150,
    batch_size=32,
    verbose=1,
    validation_split=0.2
)

loss, accuracy = model2.evaluate(X_test, y_test)
print(f"Improved Model Accuracy: {accuracy:.4f}")
print(f"Improved Model Loss: {loss:.4f}")

model2.save("tic-tac-toe-improved.keras")
# Out:
# Epoch 1/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6487 - loss: 0.6580 - val_accuracy: 0.6818 - val_loss: 0.6224
# Epoch 2/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6454 - loss: 0.6387 - val_accuracy: 0.6818 - val_loss: 0.6168
# Epoch 3/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6487 - loss: 0.6364 - val_accuracy: 0.6818 - val_loss: 0.6151
# Epoch 4/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6520 - loss: 0.6215 - val_accuracy: 0.7013 - val_loss: 0.6113
# Epoch 5/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6765 - loss: 0.6179 - val_accuracy: 0.6818 - val_loss: 0.6074
# Epoch 6/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6977 - loss: 0.6086 - val_accuracy: 0.7013 - val_loss: 0.6039
# Epoch 7/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6977 - loss: 0.6020 - val_accuracy: 0.7013 - val_loss: 0.6020
# Epoch 8/150
# ...

# %%
import numpy as np
import pandas as pd

from tensorflow.keras.models import load_model

# Load the saved model
model = load_model("tic-tac-toe-improved.keras")

# Pick a few random rows from the test set
indices = np.random.choice(len(X_test), size=5, replace=False)

X_sample = X_test[indices]
y_sample = y_test.iloc[indices]

# Make predictions (probabilities)
pred_probs = model.predict(X_sample)

# Convert probabilities → class labels
pred_classes = np.argmax(pred_probs, axis=1)

print("Predictions:", pred_classes)
print("True Labels:", list(y_sample))

# Predictions in a nice table
df_results = pd.DataFrame({
    "Predicted": pred_classes,
    "Actual": y_sample.values
})

print(df_results)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predictions: [0 1 0 1 1]
# True Labels: [0, 1, 0, 1, 1]
#    Predicted  Actual
# 0          0       0
# 1          1       1
# 2          0       0
# 3          1       1
# 4          1       1

# %% [markdown]
# They match 5 out of 5 correct → 100% accuracy on this small sample.

# %% [markdown]
# **Which approach(es) did you find helpful to improve your model performance?**

# %% [markdown]
# 1st experiment vs 2nd experiment
# - **1.** compile: `"adam"` vs **2.** `tf.keras.optimizers.Adam(learning_rate=0.001)` absolutelly the same.
# - **2.** added ` Dropout(0.2)` to prevent overfitting.
# - **1.** 3 layers layer (32 → 16 neurons)vs **2.** 4 layers(64 → 32 → 16 neurons). -> the model now captures more complex patterns
# - epochs **1.** 50 vs **2.** 150

# %% [markdown]
# ### Some Theory:
# 1️⃣ Softmax: Softmax is an activation function used in the output layer for classification problems. Comverts raw numbers to probabilities. **softmax([3.0,1.0])=[0.88,0.12]**
#
# 2️⃣ Output Layer: The last layer of the network that produces the final predictions.
#
# 3️⃣ Hidden Layer: Layers between the input and output layers. | They are called “hidden” because we don’t see their outputs directly
#
# 4️⃣ Difference between `input_dim` and `tf.keras.Input(shape=(9,))`: Both do the same for simple models — just different style.
#
# 5️⃣ Optimizer: algorithm that updates the model’s weights during training to minimize the loss function. `optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
# `
#
# ✅ Key points for my case - LOSS cases:
#
# - Don't switch `sparse_categorical_crossentropy` unless:
#
#     1. You change labels to **one-hot** → then use `categorical_crossentropy`
#
#     2. You change the output layer to **1 neuron** with `sigmoid` → then use `binary_crossentropy`
#
# Using the wrong loss will break training or give poor predictions.
#
# | Loss                            | Use Case                        | Output Layer | Labels   |
# | ------------------------------- | ------------------------------- | ------------ | -------- |
# | sparse_categorical_crossentropy | Multi-class integer labels      | softmax      | integers |
# | categorical_crossentropy        | Multi-class one-hot labels      | softmax      | one-hot  |
# | binary_crossentropy             | Binary classification           | sigmoid      | 0 or 1   |
# | mean_squared_error              | Regression (or numeric outputs) | any          | numeric  |
#
# 6️⃣ Inference: is the process of using a trained model to make predictions on new data.
